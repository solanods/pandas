# %%
import pandas as pd
import datetime
pd.set_option('display.max_rows', 3000)

# %%
df = pd.read_csv('/home/sol/PycharmProjects/pandas/moodle/databases/logs_004 - Marcha à Ré_20220620-1120.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10254 entries, 0 to 10253
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hora                10254 non-null  object
#  1   Nome completo       10254 non-null  object
#  2   Usuário afetado     10254 non-null  object
#  3   Contexto do Evento  10254 non-null  object
#  4   Componente          10254 non-null  object
#  5   Nome do evento      10254 non-null  object
#  6   Descrição           10254 non-null  object
#  7   Origem              10254 non-null  object
#  8   endereço IP         10254 non-null  object
# dtypes: object(9)
# memory usage: 721.1+ KB

# %%
#verify activities
df['Nome do evento'].value_counts()
# Out:
# Módulo do curso visualizado                        2191
# Curso visto                                        1759
# Conclusão da atividade do curso atualizada         1471
# Tentativa do questionário visualizada              1116
# Evento atualizado no calendário                     994
# Evento criado no calendário                         497
# Usuário recebeu nota                                342
# Tentativa do questionário revisada                  243
# Resumo da tentativa do questionário visualizada     235
# Papel atribuído                                     207
# Usuário inscrito no curso                           207
# Tentativa do questionário iniciada                  194
# Tentativa do questionário entregue                  182
# Session report viewed                               178
# Resposta enviada                                    158
# Lista de usuários vistos                             52
# Módulo de curso atualizado                           45
# ...

# %%
#remover duplicados
df = df.drop_duplicates()

# %%
#change case
df['Nome completo'] = df['Nome completo'].str.title()

# %%
# Get names of indexes for which column Nome completo has value -
indexNames = df[ df['Nome completo'] == '-' ].index
# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)

# %%
df['Nome completo'].value_counts()
# Out:
# Vagner Silva Dos Santos                     1136
# Solano Cruz Junior                          1128
# Patricia Crestani                            179
# Eloy Roberto Mierlo Antunes                   79
# João Batista Linck                            75
# Edelvira Silva                                67
# Hortencia Iara Do Canto                       64
# Zuleika Splitt                                64
# Marcos Dos Santos Miranda                     62
# Senair Bressan                                61
# Julio César Corrêa Da Silva                   60
# Gilson Azambuja De Oliveira                   60
# Sérgio Batista Da Silva                       58
# Lauri Rohrig Da Costa                         58
# Kelly Lima Gobatto                            57
# Ronaldo Oliveira Da Silva                     57
# Cláudio Cesar Paim                            56
# Mirian Da Silva Elesbao                       55
# Cesar Eduardo Wagner                          52
# ...

# %%
#reset index
df.reset_index(inplace=True, drop=True)

# %%
df = df.drop(columns=['Usuário afetado', 'endereço IP'])

# %%
df.to_csv('/home/sol/Documentos/datasets/trafego_tratado.csv')
