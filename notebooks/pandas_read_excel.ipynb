# %%
import pandas as pd

# %%
table = pd.read_excel('C:/Users/Admin/Documents/controlefinanceiro.xlsx')

# %%
table.head()
# Out:
#   Unnamed: 0          Unnamed: 1  JANEIRO  FEVEREIRO    MARÇO    ABRIL  \
# 0   Entradas             Salário  7098.18    5681.89  7038.71  6249.24
# 1        NaN              Outros   538.65    1048.00   340.48   231.82
# 2        NaN  Saldo Mês Anterior    52.95      46.50  -759.41   451.93
# 3  Sub-Total           Sub-Total  7689.78    6776.39  6619.78  6932.99
# 4        NaN                 NaN      NaN        NaN      NaN      NaN
#
#       MAIO     JUNHO     JULHO   AGOSTO  SETEMBRO  OUTUBRO  Unnamed: 12  \
# 0  6106.07   6615.94  17342.82  1829.85   5019.81  4304.87          NaN
# 1      NaN   4615.56       NaN  3500.00       NaN      NaN          NaN
# 2  -147.42    311.70   4533.30   129.97    494.06   176.51          NaN
# 3  5958.65  11543.20  21876.12  5459.82   5513.87  4481.38          NaN
# 4      NaN       NaN       NaN      NaN       NaN      NaN          NaN
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
table.head(10)
# Out:
#      Unnamed: 0                          Unnamed: 1      JANEIRO   FEVEREIRO  \
# 0      Entradas                             Salário  7098.180000  5681.89000
# 1           NaN                              Outros   538.650000  1048.00000
# 2           NaN                  Saldo Mês Anterior    52.950000    46.50000
# 3     Sub-Total                           Sub-Total  7689.780000  6776.39000
# 4           NaN                                 NaN          NaN         NaN
# 5        Saídas              GASTOS FIXOS (PRECISO)     0.474369     0.63135
# 6   ALIMENTAÇÃO                          Comer fora   367.900000   257.45000
# 7       MORADIA             Apartamento, Condomínio  1713.190000  2035.90000
# 8    TRANSPORTE        Uber, passagens, van escolar   420.710000    25.00000
# 9  SUPERMERCADO  Padarias, fruteiras, açougue, etc.   370.000000   938.57000
#
#          MARÇO       ABRIL         MAIO         JUNHO        JULHO  \
# ...

# %%
table.query('FEVEREIRO < 1000').head()
# Out:
#      Unnamed: 0                          Unnamed: 1     JANEIRO  FEVEREIRO  \
# 2           NaN                  Saldo Mês Anterior   52.950000   46.50000
# 5        Saídas              GASTOS FIXOS (PRECISO)    0.474369    0.63135
# 6   ALIMENTAÇÃO                          Comer fora  367.900000  257.45000
# 8    TRANSPORTE        Uber, passagens, van escolar  420.710000   25.00000
# 9  SUPERMERCADO  Padarias, fruteiras, açougue, etc.  370.000000  938.57000
#
#         MARÇO       ABRIL         MAIO        JUNHO       JULHO      AGOSTO  \
# 2 -759.410000   451.93000  -147.420000   311.700000  4533.30000  129.970000
# 5    0.458787     0.49636     0.403101     0.459152     0.14472    1.952849
# 6  198.750000   311.50000   313.450000   492.500000   426.23000  356.000000
# 8   45.000000    64.60000    84.000000   265.500000   106.09000  150.100000
# 9  708.500000  1810.00000  1170.170000  1089.360000   563.16000  259.200000
#
#      SETEMBRO  OUTUBRO  Unnamed: 12  Unnamed: 13
# ...

# %%
table.query('FEVEREIRO < 1000')
# Out:
#          Unnamed: 0                          Unnamed: 1      JANEIRO  \
# 2               NaN                  Saldo Mês Anterior    52.950000
# 5            Saídas              GASTOS FIXOS (PRECISO)     0.474369
# 6       ALIMENTAÇÃO                          Comer fora   367.900000
# 8        TRANSPORTE        Uber, passagens, van escolar   420.710000
# 9      SUPERMERCADO  Padarias, fruteiras, açougue, etc.   370.000000
# 10  FONE E INTERNET                                 NaN   495.360000
# 13              NaN            GASTOS VARIÁVEIS (QUERO)     0.587752
# 15          PESSOAL     Saúde, salão, cursos, concursos   654.860000
# 16        TRIATHLON              Natação, bike, corrida    59.000000
# 17            LAZER    Festas, saídas, viagens, cultura    91.000000
# 19           OUTROS                                 NaN  1046.400000
# 21              NaN                APLICAÇÕES (RESERVA)     0.014673
# 22      PREVIDÊNCIA                                 NaN   104.150000
# ...

# %%
table.query('FEVEREIRO < 1000 & FEVEREIRO > 200')
# Out:
#          Unnamed: 0                          Unnamed: 1  JANEIRO  FEVEREIRO  \
# 6       ALIMENTAÇÃO                          Comer fora   367.90     257.45
# 9      SUPERMERCADO  Padarias, fruteiras, açougue, etc.   370.00     938.57
# 10  FONE E INTERNET                                 NaN   495.36     330.34
# 16        TRIATHLON              Natação, bike, corrida    59.00     405.00
# 19           OUTROS                                 NaN  1046.40     421.88
#
#      MARÇO    ABRIL     MAIO    JUNHO    JULHO  AGOSTO  SETEMBRO  OUTUBRO  \
# 6   198.75   311.50   313.45   492.50   426.23  356.00    209.50      NaN
# 9   708.50  1810.00  1170.17  1089.36   563.16  259.20    580.91      NaN
# 10  347.57   478.16   320.08   491.86   524.51  509.44    333.46      NaN
# 16     NaN   168.00   170.00   342.90   184.70  167.90    167.90      NaN
# 19  289.39   593.50   699.10  1754.83  5438.02  634.99    444.00      NaN
#
#     Unnamed: 12  Unnamed: 13
# 6           NaN          NaN
# ...
