# %% [markdown]
# <a href="https://colab.research.google.com/github/solanods/pandas/blob/master/alteracoes_rmops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
from re import search

import pandas as pd
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)

from google.colab import drive
drive.mount('/content/drive')

from datetime import date
# Out:
# Mounted at /content/drive

# %%
# Carregamento dos dados
df_original = pd.read_excel('/content/PRMS_09_SET_2022ontem.xlsm', sheet_name='RMOP')
df_alterado = pd.read_excel('/content/PRMS_09_SET_2022.xlsm', sheet_name='RMOP')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
# Funcao limpeza de dados

def tratarDataframe(df):
  
  # Selecionar colunas de interesse
  df = df.iloc[:,[3,5,6,7,8,11,16,17,18,19]]

  # Renomear colunas
  df = df.rename({'Unnamed: 3': 'DIA',
                  'Unnamed: 5': 'PREVISTO',
                  'Unnamed: 6': 'ESCALA',
                  'Unnamed: 7': 'TOTVS',
                  'Unnamed: 8': 'JORNADA',
                  'Unnamed: 11': 'ENTRADA',
                  'Unnamed: 16': 'CODIGO',
                  'Unnamed: 17': 'DESCRICAO',
                  'Unnamed: 18': 'OBSERVACOES',
                  'Unnamed: 19': 'RE_SGT'}, axis = 1)

  # Remover nan
  df = df.fillna('-')

  # Obter lista com nome de todos operadores
  operadores = []
  for linha in df.index:
    if search ('[A-Z]+', str(df['DIA'][linha])):
      operadores.append(df['DIA'][linha])

  operadores = [operador for operador in operadores if operador.isupper()]

  # Extrair rmop
  i = 3
  j =38
  R = []
  df['NOME'] = ''
  df['RE'] = ''
  for operador in operadores:
    df['NOME'].loc[i:j] = operador
    rmop_operador = df.loc[i:j]
    R.append(rmop_operador)
    df['RE'].loc[i:j] = df['ENTRADA'].loc[i:j].iloc[0]
    i+=66
    j+=66

  return df

# %%
df_original = tratarDataframe(df_original)
df_alterado = tratarDataframe(df_alterado)

# %%
# Criar novo df somente com os índices modificados, ou seja, as diferenças entre ambos
rmops_alterado = pd.concat([df_original,df_alterado]).drop_duplicates(keep=False)

# %%
# Resultado mostra os indices originais e alterados em sequencia
rmops_alterado
# Out:
#       DIA PREVISTO ESCALA TOTVS JORNADA   ENTRADA CODIGO           DESCRICAO  \
# 1283   22     TRAB     MA   3-C     NPT  21:30:00   C083        Troca Missão
# 2076   23     TRAB     G3  17-Q     07M  05:10:00      -                   -
# 2081   28      FOL     G3  17-Q     FOL                -                   -
# 2472   23      FOL     J1  13-M     FOL                D  Disponível para HE
# 2476   27     TRAB     J1  13-M     11T  12:00:00      -                   -
# 3005   28     TRAB    EAA   2-B    EMP1   TRAR EX    EMP   Lançar em jornada
# 3255   14      FOL     J2  13-M     09T  13:30:00   HEFT      HE folga TARDE
# 3459   20     TRAB     O1   3-C     12T  14:40:00      -                   -
# 3593   22      FOL     M2   7-G     FOL                -                   -
# 6958   21     TRAB     L2   9-I     10T  12:00:00   C300     HE extensão jor
# 7026   23     TRAB    Y10     _     11T  12:00:00   C083        Troca Missão
# 7618   21     TRAB     K5  11-K     25T  14:30:00   C083        Troca Missão
# 7619   22     TRAB     K5  11-K     28T  12:00:00   C083        Troca Missão
# 7751   22     TRAB     OA   9-I     TPT  13:15:00   C083        Troca Missão
# 7949   22     TRAB     K6  11-K     08T  12:20:00   C083        Troca Missão
# 7950   23     TRAB     K6  11-K     15T  13:30:00   C500             Permuta
# 8213   22     TRAB      -   1-A     NPT  21:30:00   C500             Permuta
# 8475   20     TRAB     P6   1-A     FAT   COLOCAR   C208            Atestado
# 8476   21     TRAB     P6   1-A     FAT   COLOCAR   C208            Atestado
# 8477   22     TRAB     P6   1-A     FAT   COLOCAR   C208            Atestado
# 9797   22     TRAB     K4  11-K     05T  13:15:00   C083        Troca Missão
# 11183  22     TRAB     P4   1-A     20T  12:30:00   C083        Troca Missão
# 11512  21     TRAB    Y13     _     FAT   COLOCAR    LDV   Lançar em jornada
# 11711  22      FOL     D4   5-E     03T  13:10:00   HEFT      HE folga TARDE
#
#                                              OBSERVACOES         RE_SGT  \
# 1283                                       C/ Trintinaia           2445
# 2076                                                   -              -
# 2081                                                   -              -
# 2472                                                   -              -
# 2476                                                   -       542/2906
# 3005                                                   -            257
# 3255                                       FALTA TORRES             252
# 3459                                                   -              -
# 3593                                                   -              -
# 3594                                                   -              -
# 4254                                                   -              -
# 5046                                                   -              -
# 5047                                                   -              -
# 5048                                                   -              -
# 5049                                                   -              -
# 5050                                                   -              -
# 5051                                                   -              -
# 6958                                                   -              -
# 7026                                                   -              -
# 7618                                                   -              -
# 7619                                                   -              -
# 7751                                                   -              -
# 7949                                                   -              -
# 7950                                                   -              -
# 8213                                                   -              -
# 8475                                                   -              -
# 8476                                                   -              -
# 8477                                                   -              -
# 9797                                                   -              -
# 11183                                                  -              -
# 11512                         Reciclagem pátio - TRE 14h           2923
# 11711                                                  -              -
# 1283                                       C/ Trintinaia      2445/2426
# 2076                                     Por 28 sol func           2426
# 2081                                     por 23 sol func           2426
# 2472                              POR 27 nec operacional              -
# 2476                              por 23 nec operacional  542/2906/2426
# 3005                                                   -              -
# 3255   FALTA TORRES . Sem intervalo nec operac.  Assu...       252/2426
# 3459                                                   -           2426
# 3593                                                   -           2426
# 3594                                                FURO           2426
# 4254                                            sol func           2426
# 5046                                        COM MADALENA           2426
# 5047                                     por 27 sol func           2426
# 5048                                     por 28 sol func           2426
# 5049                                            sol func           2426
# 5050                                     por 24 sol func           2426
# 5051                                     por 25 sol func           2426
# 6958                       nec oper recolhimento atrasou           2426
# 7026                                            COM INES           2426
# 7618                            nec oper falta Vanderlei           2426
# 7619                                       COM VALLERIUS           2426
# 7751                                   Ajuste de efetivo           2426
# 7949                                   Ajuste de efetivo           2426
# 7950                                            nec oper           2426
# 8213                                   Ajuste de efetivo           2426
# 8475                                                   -           2426
# 8476                                                   -           2426
# 8477                                                   -           2426
# 9797                                        C/ VALLERIUS           2426
# 11183              C/ SAUL +C083 MARTA Ajuste de efetivo           2426
# 11512                            TREINAMENTO MESARIO TRE      2923/2426
# 11711                                           nec oper           2426
#
#             NOME    RE
# 1283   BARCELLOS   542
# 2076      CIBELE  3193
# 2081      CIBELE  3193
# 2472    COITINHO  3609
# 2476    COITINHO  3609
# 3005       DIEGO  2394
# 3255        EDNA  3094
# 3459      ENEDIR   525
# 3593    FAGUNDES  1576
# 3594    FAGUNDES  1576
# 4254      FULBER  1252
# 5046        INES  2424
# 5047        INES  2424
# 5048        INES  2424
# 5049        INES  2424
# 5050        INES  2424
# 5051        INES  2424
# 6958      MACEDO   850
# 7026    MADALENA   972
# 7618       MARTA  1425
# 7619       MARTA  1425
# 7751    MAURICIO  2945
# 7949     MIRANDA   577
# 7950     MIRANDA   577
# 8213    NOGUEIRA  1643
# 8475     PACHECO   880
# 8476     PACHECO   880
# 8477     PACHECO   880
# 9797        SAUL   585
# 11183  VALLERIUS  1388
# 11512     VIEIRA  3317
# 11711      WIRTI  2398
# 1283   BARCELLOS   542
# 2076      CIBELE  3193
# 2081      CIBELE  3193
# 2472    COITINHO  3609
# 2476    COITINHO  3609
# 3005       DIEGO  2394
# 3255        EDNA  3094
# 3459      ENEDIR   525
# 3593    FAGUNDES  1576
# 3594    FAGUNDES  1576
# 4254      FULBER  1252
# 5046        INES  2424
# 5047        INES  2424
# 5048        INES  2424
# 5049        INES  2424
# 5050        INES  2424
# 5051        INES  2424
# 6958      MACEDO   850
# 7026    MADALENA   972
# 7618       MARTA  1425
# 7619       MARTA  1425
# 7751    MAURICIO  2945
# 7949     MIRANDA   577
# 7950     MIRANDA   577
# 8213    NOGUEIRA  1643
# 8475     PACHECO   880
# 8476     PACHECO   880
# 8477     PACHECO   880
# 9797        SAUL   585
# 11183  VALLERIUS  1388
# 11512     VIEIRA  3317
# 11711      WIRTI  2398

# %%
# Criar campo data
data_atual = date.today()
rmops_alterado['ALTERADO_EM'] = data_atual

# %%
# Salvar no google drive
rmops_alterado.to_excel(f'/content/drive/MyDrive/alteracoesrmop{data_atual}.xlsx')

# %%
# Numero de alteracoes
num_alteracoes = len(rmops_alterado.index)/2

# %%
# String para arquivar
dados = str(data_atual) + '   N°_RMOPS_ALTERADOS: ' + str(int(num_alteracoes))

# %%
dados
# Out:
# '2022-09-22   N°_RMOPS_ALTERADOS: 32'

# %%
# Salvar em arquivo texto
file = open('/content/drive/MyDrive/alteracoes_rmop_contador.txt', 'a')
file.write(dados + '\n')
file.close()
